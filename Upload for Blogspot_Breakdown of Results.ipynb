# %% [markdown]
# ---
# ---
#
# <h1 align=center><font size = 5>Data Science Capstone Project: The Battle of Neighborhoods (Wards)</font></h1>
#
# ---
# ---
#
#
# # 1) Introduction/ Business Problem
#
# ---
#
#
# ### Problem Statement: Prospects of a Restaurant Near Higher-Income areas in Richmond, USA
#
# *This study aims at helping someone planning on opening a new restaurant in the Richmond area chose the right location by providing data about income and population of each in the Richmond Area as well as competitors nearby.*
#
# - **The Coronavirus pandemic has led to an increase in stay-at-home orders affecting school and office closures to mitigate the spread of the virus**
#
# - **The Coronavirus has impacted restaurants to minimize social interaction among customers in the Washington DC area, resulting in only having a carry-out only policy. There has also been an increase in meal-prepping services.**
#      *This provides a window of opportunity for a meal prepping restaurant to target residents working from home.*
#
# - **In 2019, Washington, D.C. had the highest population density in the United States, with 11,570 people per square mile.**
#     *The high population density is an apealing factor to start a business.*
#     - Source: https://www.areavibes.com/richmond-va/demographics/
#
#
#
# ### Target Audience:
#
# *What type of clients or a group of people would be interested in this project?*
#
# 1. **Investors** that seek to invest in opening a company. This analysis will highlight potential areas to start or expand a business, targeting individuals with a higher likelihood of paying for meal-prepping meals.
# 2. **Working From Home Population** ordering meal-ready meals looking for a nearby meal-prepping restaurant.
#
# 3. **Freelancers** looking into opening a restaurant. This will provide an analysis whether the venture is feasible or not.
#
#
# ---
# ---
#
#
# # 2) Downloading and Prepping Data
#
# ---
#
# **1.** I obtained a geoJSON file with the commonly accepted boundaries of city neighborhoods within the city of Richmond.
#
#
#    * <a href> https://data.richmondgov.com/Unique-and-Inclusive-Neighborhoods/Neighborhoods/e9k6-65id </a>
#
#
# **2.** The data I used is Esri's *Richmond Area Wealthiest Zip Codes
# Ranked by 2013 Median Household Income* report.
# *To provide stakeholders with the neccesary information, I will be using the most recent information available of median household income broken down by zipcodes.*
#
#    * <a href> https://www.esri.com/library/analysis/2014-wealthiest-zip-codes.pdf <a>
#
# **3.** I will leverage Foursquare data to display the current restaurants in each region. I will layer population wealth and restaurants to find the best location in relation to the top wealthiest zip codes.
#
# ---
# ---
#
#
# # 3) Methodology
#
# ---
#
# Methodology section which represents the main component of the report where you discuss and describe any exploratory data analysis that you did, any inferential statistical testing that you performed, and what machine learnings were used and why.
#
# I used the *Richmond Area Wealthiest Zip Codes
# Ranked by 2013 Median Household Income* report and merged this data with a zip code list. This was used to cluster and visually display the wealthier and more populational neighborhoods. Foursquare data to display the current American restaurants in each region. There is no option in Foursqaure for meal-prepping services so I used American Restaurants to filter. I also used k-means to identify the best k.
#
# ---
# ---
#
# # 4) Results
#
# ---
#
# Results section where you discuss the results.
#
#
# Hanover and Chester are the most economically efficient for an American Restaurant.
#
# ---
# ---
#
# # 5) Discussion
#
# ---
#
# Discussion section where you discuss any observations you noted and any recommendations you can make based on the results.
#
# When I first decided to create this study I was expecting to find more areas of near downtown Richmond  since it is becoming a hot spot or Midlothian since that has the highest Average Income per household.
#
# ---
# ---
#
# # 6) Conclusion
#
# ---
#
# Conclusion section where you conclude the report.
#
# This report may be helpful for someone planning on opening a business in the Richmond area, by comparing the wealthier locations. However it may not cover all variables such as access to public transportation, Coronavirus impacts, choice in families eating out or even the restaurants profiles, so it shall not be used as a single decision making tool.
