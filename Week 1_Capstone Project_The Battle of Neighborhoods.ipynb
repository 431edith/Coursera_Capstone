# %% [markdown]
# <a> <img src = "https://bit.ly/2Siw7wS" width = 650, length = 200> </a>
#
# ---
# ---
#
# <h1 align=center> ## Data Science Capstone Project: The Battle of Neighborhoods (Wards) </font> </h1>
#
# ---
# ---
#
# ## 1) Introduction/ Business Problem
#
# ---
#
# *Clearly define a problem or an idea of your choice, where you would need to leverage the Foursquare location data to solve or execute. Remember that data science problems always target an audience and are meant to help a group of stakeholders solve a problem, so make sure that you explicitly describe your audience and why they would care about your problem.*
#
# ### Problem Statement: Prospects of a Restaurant Near Higher-Income areas in Washington DC, USA
#
# *This study aims at helping someone planning on opening a new restaurant in the Washington,D.C. area chose the right location by providing data about income and population of each Ward as well as competitors nearby.*
#
# - **The Coronavirus pandemic has led to an increase in stay-at-home orders affecting school and office closures to mitigate the spread of the virus**
#
# - **The Coronavirus has impacted restaurants to minimize social interaction among customers in the Washington DC area, resulting in only having a carry-out only policy. There has also been an increase in meal-prepping services.**
#      *This provides a window of opportunity for a meal prepping restaurant to target residents working from home.*
#
# - **In 2019, Washington, D.C. had the highest population density in the United States, with 11,570 people per square mile.**
#     *The high population density is an apealing factor to start a business.*
#     - Source: https://www.statista.com/statistics/183588/population-density-in-the-federal-states-of-the-us/
#
#
#
# ### Target Audience:
#
# *What type of clients or a group of people would be interested in this project?*
#
# 1. **Investors** that seek to invest in opening a company. This analysis will highlight potential areas to start or expand a business, targeting individuals with a higher likelihood of paying for meal-prepping meals.
# 2. **Working From Home Population** ordering meal-ready meals looking for a nearby meal-prepping restaurant.
#
# 3. **Freelancers** looking into opening a restaurant. This will provide an analysis whether the venture is feasible or not.
#
#
# ---
# ---
#
#
# ## 2) Downloading and Prepping Data
#
# ---
#
# *Describe the data that you will be using to solve the problem or execute your idea. Remember that you will need to use the Foursquare location data to solve the problem or execute your idea. You can absolutely use other datasets in combination with the Foursquare location data. So make sure that you provide adequate explanation and discussion, with examples, of the data that you will be using, even if it is only Foursquare location data.*
#
# **1.** Washington D.C. is broken down into 8 wards 34 neighborhoods. I will first start with obtaining the zip code locations for these wards and neighboods to be able to cluster them. I also obtained geoJSON file with the neighborhood names:
#
#    * <a href> https://en.wikipedia.org/wiki/Neighborhoods_in_Washington,_D.C. </a>
#
#    * <a href> https://opendata.dc.gov/datasets/5637d4bb43a34668b19fe630120d2b70_4/geoservice?geometry=-77.529%2C38.713%2C-76.499%2C39.087 </a>
#
#    * <a href> https://github.com/benbalter/dc-maps/blob/master/maps/neighborhood-names-centroid.geojson </a>
#
# **2.** I will use Washington D.C. median household income per zip code.
# *To provide stakeholders with the neccesary information, I will be using the most recent information available of median household income broken down by zipcodes.*
#
#    * <a href> http://zipatlas.com/us/dc/washington/zip-code-comparison/median-household-income.htm <a>
#
# **3.** I will leverage Foursquare data to display the current restaurants in each region.
#
#
# ***CONCLUSION:*** In order to segement the neighborhoods and explore them, I will need a dataset that contains the 8 wards and the 34 neighborhoods that exist in each ward as well as the the latitude and logitude coordinates of each neighborhood to layer population wealth and restaurants in those regions.
#
# ---
# ---
# ---
